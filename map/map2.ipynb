# %%
def celcius_para_fahrenheit(c):
    return (c * 9/5) + 32

# %%
temperaturas_celcius = [0, 20, 37, 100]
temperaturas_fahrenheit = map(celcius_para_fahrenheit, temperaturas_celcius)
list(temperaturas_fahrenheit)
# Out:
# [32.0, 68.0, 98.6, 212.0]
